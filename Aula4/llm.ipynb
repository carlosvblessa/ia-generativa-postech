# %% [markdown]
# O código demonstra como usar a biblioteca Transformers da Hugging Face para gerar texto com um modelo pré-treinado, utilizando o GPT-2. Ele inclui a tokenização do texto de entrada, a geração de uma sequência de texto com base nesse input, e a decodificação do resultado para um formato legível. Esse tipo de código é comum em tarefas de geração de texto, como completar sentenças ou criar parágrafos a partir de um prompt inicial.

# %%
# !pip install transformers

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='gpt2')

# Gerando texto
output = generator("Once upon a time", max_length=100, num_return_sequences=1, temperature=0.7, top_k=50, top_p=0.9)
print(output[0]['generated_text'])
# Out:
# 2025-11-14 16:34:15.315936: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-14 16:34:15.352006: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-14 16:34:16.428315: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 from transformers import pipeline
# ----> 3 generator = pipeline('text-generation', model='gpt2')
#       5 # Gerando texto
#       6 output = generator("Once upon a time", max_length=100, num_return_sequences=1, temperature=0.7, top_k=50, top_p=0.9)
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/pipelines/__init__.py:1027, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1025 if isinstance(model, str) or framework is None:
#    1026     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1027     framework, model = infer_framework_load_model(
#    1028         adapter_path if adapter_path is not None else model,
#    1029         model_classes=model_classes,
#    1030         config=config,
#    1031         framework=framework,
#    1032         task=task,
#    1033         **hub_kwargs,
#    1034         **model_kwargs,
#    1035     )
#    1037 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1039 # Check which preprocessing classes the pipeline uses
#    1040 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/pipelines/base.py:268, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     266         classes.append(_class)
#     267 if look_tf:
# --> 268     _class = getattr(transformers_module, f"TF{architecture}", None)
#     269     if _class is not None:
#     270         classes.append(_class)
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/models/gpt2/modeling_tf_gpt2.py:25
#      22 import numpy as np
#      23 import tensorflow as tf
# ---> 25 from ...activations_tf import get_tf_activation
#      26 from ...modeling_tf_outputs import (
#      27     TFBaseModelOutputWithPastAndCrossAttentions,
#      28     TFCausalLMOutputWithCrossAttentions,
#      29     TFSequenceClassifierOutputWithPast,
#      30 )
#      31 from ...modeling_tf_utils import (
#      32     TFCausalLanguageModelingLoss,
#      33     TFConv1D,
#    (...)     41     unpack_inputs,
#      42 )
#
# File ~/FCD/POSTECH/modulo4/04-GenerativeIA/venv/lib/python3.12/site-packages/transformers/activations_tf.py:27
#      24     import keras
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#      35     """
#      36     Gaussian Error Linear Unit. Original Implementation of the gelu activation function in Google Bert repo when
#      37     initially created. For information: OpenAI GPT's gelu is slightly different (and gives slightly different results):
#      38     0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3)))) Also see
#      39     https://huggingface.co/papers/1606.08415
#      40     """
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %% [markdown]
# A repetição é um problema comum em modelos de linguagem quando eles não têm restrições adequadas ou parâmetros ajustados para promover a diversidade no texto gerado. Para reduzir a repetição e obter um texto mais variado, você pode ajustar alguns parâmetros adicionais.

# %% [markdown]
# 1. Reduzir a temperature:
#
# A temperature controla a aleatoriedade das escolhas do modelo. Valores mais baixos (próximos a 0) tornam a geração mais conservadora e determinística, enquanto valores mais altos (próximos a 1) aumentam a diversidade, mas podem resultar em texto menos coerente.
# Tente diminuir a temperature para ver se isso reduz a repetição.
#
# 2. Aumentar top_p e top_k:
#
# top_k restringe o modelo a escolher entre as k palavras mais prováveis.
#
# top_p (ou "nucleus sampling") é uma técnica que permite que o modelo escolha palavras até que a soma de suas probabilidades atinja um determinado limiar.
# Aumentando esses valores, você permite que o modelo considere mais opções, o que pode ajudar a evitar a repetição.

# %%
from transformers import pipeline

# Usar o pipeline para geração de texto
generator = pipeline('text-generation', model='gpt2')

# Gerar mais texto com ajustes para reduzir a repetição
output = generator(
    "Once upon a time",
    max_length=100,
    num_return_sequences=1,
    temperature=0.6,   # Pode tentar ajustar para 0.6 ou 0.5
    top_k=50,
    top_p=0.85         # Pode tentar ajustar para 0.9 ou 0.85
)

print(output[0]['generated_text'])
